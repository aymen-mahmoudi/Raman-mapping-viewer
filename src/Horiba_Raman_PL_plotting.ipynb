# %%
from PL_Horiba import*

# %%
path = "..\\tests\map_test.txt"
colormap = sns.color_palette("YlOrBr_r",100)
title = 'Max Height (counts)'
dpi = 100
binary_mode = False
threshold = 250

Horiba_Raman_PL_plot(path,colormap,dpi,title,binary_mode,threshold)
